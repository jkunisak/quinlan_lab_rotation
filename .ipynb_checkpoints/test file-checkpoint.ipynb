# %%
import cyvcf2
import sys
import exter ## exter.py file has to be in the working directory 
import re
import pandas as pd
import numpy as np
from collections import defaultdict
from scipy.stats import percentileofscore
import subprocess
from IPython.display import SVG
gff_path = "/Users/jasonkunisaki/git/quinlan_lab_rotation/reference/Homo_sapiens.GRCh37.82.chr20.gff3" 
wgs_vcf_path = "/Users/jasonkunisaki/git/quinlan_lab_rotation/reference/gnomad.genomes.r2.1.1.exome_calling_intervals.sites.vcf.bgz"
exome_vcf_path = "/Users/jasonkunisaki/git/quinlan_lab_rotation/reference/gnomad.exomes.r2.1.1.sites.20.vcf.bgz"
sift_polyphen_filter = True
sift_cutoff = 0.03
polyphen_cutoff = 0.6

# %%
def isfunctional(csq):
    return any(c in csq['Consequence'] for c in ('stop_gained', 'stop_lost', 'start_lost', 
                                                 'initiator_codon_variant', 'rare_amino_acid_variant', 
                                                 'missense_variant', 'protein_altering_variant', 
                                                 'frameshift_variant', 'inframe_insertion', 'inframe_deletion')) \
    or (('splice_donor_variant' in csq['Consequence'] or 'splice_acceptor_variant' in csq['Consequence']) \
        and 'coding_sequence_variant' in csq['Consequence'])

# %%
def processVCF(vcf_path, gff_path, sift_polyphen_filter, sift_cutoff, polyphen_cutoff, type="exome"):
    ## Read in the VCF file 
    vcf = cyvcf2.VCF(vcf_path)
    
    ## Get the VEP description fields into a 'list'
    kcsq = vcf["vep"]["Description"].split(":")[1].strip(' "').split("|")
    
    ## Read in the gff transcript file and subset calls from chr20
    transcripts = exter.read_gff(gff_path)
    transcripts20 = transcripts["20"] # get chr20

    ## Make an empty dictionary 
    local_by_gene = defaultdict(list)
    
    ## For each variant in the VCF file: 
    for variant in vcf:
        if variant.CHROM != "20": continue
        ## Remove variants that have "None, PASS, SEGDUP, or LCR" as the filter result
        ## NOTE: 'continue' will remove variants without these FILTER results
        if not (variant.FILTER is None or variant.FILTER in ["PASS", "SEGDUP", "LCR"]):
                continue
        ## Get the variant 'INFO' field from the VCF file for each variant
        info = variant.INFO
        ## Set the functional consequence of the variant to 'False'
        any_functional = False
        ## Merge the kcsq description keys with 
        csqs = [dict(zip(kcsq, c.split("|"))) for c in info['vep'].split(",")]

        ## For all variant/consequences that are within protein_coding regions
        for csq in (c for c in csqs if c['BIOTYPE'] == 'protein_coding'):
            ## NOTE: 'continue' will ignore variants that are intronic 
            if csq['Feature'] == '' or csq['EXON'] == '': 
                continue #or csq['cDNA_position'] == '': continue
            ## Check to see if the variant's consequence is functional (based on the mutation types listed above)
            ## NOTE: 'continue' will ignore variants that are not functional
            if not isfunctional(csq): 
                continue
            ## Assigns True to the variant as functional if it is NOT intronic and is deemed as functional by the 'isfunctional' function
            any_functional = True

            ## Get the exonic positions of the variants
            local = transcripts20.localize(variant.start, variant.end)

            ## Get the VAF of the variant
            vaf = variant.INFO.get('AF')

            ## Get the SIFT/PolyPhen results (IS THIS RIGHT)
            SIFT = csq["SIFT"]
            PolyPhen = csq["PolyPhen"]

            ## Get the reference allele 
            ref_allele = variant.REF

            ## Get string for the mutation 
            mut = []
            for alt in variant.ALT: 
                mut.append(ref_allele + ">" + alt) 

            ## Remove variants that do not meet a specific VAF cutoff 
            # if vaf < 0.0000001: continue

            ## Perform SIFT and Polyphen filters to remove the least delterious/damaging variant(s)
            ## Go through each pair of scores and check if the varaint has SIFT and PolyPhen scores
            sift_score = sift_cutoff + 0.1
            polyphen_score = polyphen_cutoff - 0.1
            if sift_polyphen_filter == True: 
                if re.findall("deleterious", SIFT):
                    sift_score = float(re.split('\)', re.split('\(', SIFT)[1])[0])
                if re.findall("damaging", PolyPhen):
                    polyphen_score = float(re.split('\)', re.split('\(', PolyPhen)[1])[0])
                ## SIFT score has to be below the sift_cutoff to pass 
                ## PolyPhen score has to be above the polyphen_cutoff to pass 
                if not sift_score < sift_cutoff and polyphen_score > polyphen_cutoff:
                    continue

            ## Remove variants that are found in duplicated segments 
            #if variant.INFO.get('segdup') == True or variant.INFO.get('lcr'): continue
            
            for l in local:
                l["chr"] = variant.CHROM ## Get the chromosome 
                l["chr_start"] = variant.start
                l["chr_stop"] = variant.end
                l["mutation"] = mut
                l["vaf"] = vaf
                l["SIFT"] = sift_score
                l["PolyPhen"] = polyphen_score
                l["type"] = type
                local_by_gene[l["gene"]].append(l)
            break
    return(local_by_gene)

# %%
wgs_local_by_gene = processVCF(vcf_path=wgs_vcf_path, gff_path=gff_path, sift_polyphen_filter=sift_polyphen_filter, sift_cutoff=sift_cutoff, polyphen_cutoff=polyphen_cutoff, type="whole genome sequencing")

# %%
wgs_local_by_gene["DEFB125"]
# Out:
# [{'gene': 'DEFB125',
#   'start': 5,
#   'stop': 6,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68356,
#   'chr_stop': 68357,
#   'mutation': ['A>G'],
#   'vaf': 3.18552010867279e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 11,
#   'stop': 12,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68362,
#   'chr_stop': 68363,
#   'mutation': ['A>T'],
#   'vaf': 0.00012747000437229872,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 22,
#   'stop': 23,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68373,
#   'chr_stop': 68374,
#   'mutation': ['C>A'],
#   'vaf': 3.1859301088843495e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 32,
#   'stop': 33,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68383,
#   'chr_stop': 68384,
#   'mutation': ['G>C'],
#   'vaf': 3.18552010867279e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.455,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 44,
#   'stop': 45,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68395,
#   'chr_stop': 68396,
#   'mutation': ['C>T'],
#   'vaf': 0.0014653400285169482,
#   'SIFT': 0.03,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 45,
#   'stop': 46,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68396,
#   'chr_stop': 68397,
#   'mutation': ['G>A'],
#   'vaf': 3.18491984216962e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 64,
#   'stop': 65,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76653,
#   'chr_stop': 76654,
#   'mutation': ['G>T'],
#   'vaf': 0.00012750999303534627,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 95,
#   'stop': 96,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76684,
#   'chr_stop': 76685,
#   'mutation': ['G>A'],
#   'vaf': 3.184709930792451e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.993,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 109,
#   'stop': 110,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76698,
#   'chr_stop': 76699,
#   'mutation': ['C>T'],
#   'vaf': 6.369830225594342e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 113,
#   'stop': 114,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76702,
#   'chr_stop': 76703,
#   'mutation': ['G>A'],
#   'vaf': 3.184509841958061e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.951,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 145,
#   'stop': 146,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76734,
#   'chr_stop': 76735,
#   'mutation': ['A>G'],
#   'vaf': 3.183700027875602e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 146,
#   'stop': 147,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76735,
#   'chr_stop': 76736,
#   'mutation': ['G>T'],
#   'vaf': 3.1840998417465016e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.507,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 181,
#   'stop': 182,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76770,
#   'chr_stop': 76771,
#   'mutation': ['C>T'],
#   'vaf': 0.0011463500559329987,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 193,
#   'stop': 194,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76782,
#   'chr_stop': 76783,
#   'mutation': ['C>T'],
#   'vaf': 3.1853200198384e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 196,
#   'stop': 197,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76785,
#   'chr_stop': 76786,
#   'mutation': ['C>T'],
#   'vaf': 3.183700027875602e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 197,
#   'stop': 198,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76786,
#   'chr_stop': 76787,
#   'mutation': ['G>C'],
#   'vaf': 3.18511993100401e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 272,
#   'stop': 273,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76861,
#   'chr_stop': 76862,
#   'mutation': ['C>T'],
#   'vaf': 3.186129833920859e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.908,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 330,
#   'stop': 331,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76919,
#   'chr_stop': 76920,
#   'mutation': ['G>A'],
#   'vaf': 0.0006371460040099919,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 386,
#   'stop': 387,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76975,
#   'chr_stop': 76976,
#   'mutation': ['C>T'],
#   'vaf': 3.18552010867279e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 388,
#   'stop': 389,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76977,
#   'chr_stop': 76978,
#   'mutation': ['G>A'],
#   'vaf': 6.369430047925562e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 404,
#   'stop': 405,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76993,
#   'chr_stop': 76994,
#   'mutation': ['C>G'],
#   'vaf': 3.1843101169215515e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 424,
#   'stop': 425,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77013,
#   'chr_stop': 77014,
#   'mutation': ['G>A'],
#   'vaf': 3.186539834132418e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'whole genome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 436,
#   'stop': 437,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77025,
#   'chr_stop': 77026,
#   'mutation': ['C>T'],
#   'vaf': 3.18511993100401e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.857,
#   'type': 'whole genome sequencing'}]

# %%
exome_local_by_gene = processVCF(vcf_path=exome_vcf_path, gff_path=gff_path, sift_polyphen_filter=sift_polyphen_filter, sift_cutoff=sift_cutoff, polyphen_cutoff=polyphen_cutoff, type="exome sequencing")

# %%
exome_local_by_gene["DEFB125"]
# Out:
# [{'gene': 'DEFB125',
#   'start': -1,
#   'stop': 0,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68350,
#   'chr_stop': 68351,
#   'mutation': ['A>G'],
#   'vaf': 3.979720077040838e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 11,
#   'stop': 12,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68362,
#   'chr_stop': 68363,
#   'mutation': ['A>C'],
#   'vaf': 3.979179837187985e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 11,
#   'stop': 12,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68362,
#   'chr_stop': 68363,
#   'mutation': ['A>T'],
#   'vaf': 0.0001949800061993301,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 12,
#   'stop': 13,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68363,
#   'chr_stop': 68364,
#   'mutation': ['T>G'],
#   'vaf': 3.9790897972125094e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 21,
#   'stop': 22,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68372,
#   'chr_stop': 68373,
#   'mutation': ['T>C'],
#   'vaf': 3.979399934905814e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 22,
#   'stop': 23,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68373,
#   'chr_stop': 68374,
#   'mutation': ['C>A'],
#   'vaf': 3.97927988160518e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 23,
#   'stop': 24,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68374,
#   'chr_stop': 68375,
#   'mutation': ['A>G'],
#   'vaf': 1.5917399650788866e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 44,
#   'stop': 45,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68395,
#   'chr_stop': 68396,
#   'mutation': ['C>T'],
#   'vaf': 0.0015282999956980348,
#   'SIFT': 0.03,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 45,
#   'stop': 46,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68396,
#   'chr_stop': 68397,
#   'mutation': ['G>A'],
#   'vaf': 1.5919800716801547e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 50,
#   'stop': 51,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68401,
#   'chr_stop': 68402,
#   'mutation': ['A>G'],
#   'vaf': 7.96013955550734e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 58,
#   'stop': 59,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76647,
#   'chr_stop': 76648,
#   'mutation': ['A>G'],
#   'vaf': 4.094470114068827e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.483,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 59,
#   'stop': 60,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76648,
#   'chr_stop': 76649,
#   'mutation': ['G>T'],
#   'vaf': 8.121889550238848e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.766,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 60,
#   'stop': 61,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76649,
#   'chr_stop': 76650,
#   'mutation': ['C>A'],
#   'vaf': 1.6239999240497127e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.766,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 64,
#   'stop': 65,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76653,
#   'chr_stop': 76654,
#   'mutation': ['G>T'],
#   'vaf': 3.234569885535166e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 68,
#   'stop': 69,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76657,
#   'chr_stop': 76658,
#   'mutation': ['C>A'],
#   'vaf': 1.2116400284867268e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 70,
#   'stop': 71,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76659,
#   'chr_stop': 76660,
#   'mutation': ['C>G'],
#   'vaf': 4.03534977522213e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 71,
#   'stop': 72,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76660,
#   'chr_stop': 76661,
#   'mutation': ['A>C'],
#   'vaf': 8.064450412348378e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 74,
#   'stop': 75,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76663,
#   'chr_stop': 76664,
#   'mutation': ['A>C'],
#   'vaf': 4.023499968752731e-06,
#   'SIFT': 0.01,
#   'PolyPhen': 0.913,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 80,
#   'stop': 81,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76669,
#   'chr_stop': 76670,
#   'mutation': ['G>T'],
#   'vaf': 4.019620064354967e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 92,
#   'stop': 93,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76681,
#   'chr_stop': 76682,
#   'mutation': ['T>C'],
#   'vaf': 3.987299805885414e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 99,
#   'stop': 100,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76688,
#   'chr_stop': 76689,
#   'mutation': ['T>A'],
#   'vaf': 1.1952100066991989e-05,
#   'SIFT': 0.01,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 100,
#   'stop': 101,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76689,
#   'chr_stop': 76690,
#   'mutation': ['T>C'],
#   'vaf': 3.984159775427543e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.951,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 101,
#   'stop': 102,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76690,
#   'chr_stop': 76691,
#   'mutation': ['G>T'],
#   'vaf': 1.1952999557252042e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.951,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 102,
#   'stop': 103,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76691,
#   'chr_stop': 76692,
#   'mutation': ['C>A'],
#   'vaf': 3.984860086347908e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 107,
#   'stop': 108,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76696,
#   'chr_stop': 76697,
#   'mutation': ['G>A'],
#   'vaf': 3.983209808211541e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 109,
#   'stop': 110,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76698,
#   'chr_stop': 76699,
#   'mutation': ['C>T'],
#   'vaf': 1.5934199836920016e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 112,
#   'stop': 113,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76701,
#   'chr_stop': 76702,
#   'mutation': ['T>G'],
#   'vaf': 3.9825699786888435e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.849,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 113,
#   'stop': 114,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76702,
#   'chr_stop': 76703,
#   'mutation': ['G>A'],
#   'vaf': 1.5929699657135643e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.951,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 113,
#   'stop': 114,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76702,
#   'chr_stop': 76703,
#   'mutation': ['G>C'],
#   'vaf': 3.9824099076213315e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.849,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 127,
#   'stop': 128,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76716,
#   'chr_stop': 76717,
#   'mutation': ['A>G'],
#   'vaf': 3.9809201552998275e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.849,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 137,
#   'stop': 138,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76726,
#   'chr_stop': 76727,
#   'mutation': ['T>C'],
#   'vaf': 3.979780103691155e-06,
#   'SIFT': 0.01,
#   'PolyPhen': 0.973,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 143,
#   'stop': 144,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76732,
#   'chr_stop': 76733,
#   'mutation': ['G>A'],
#   'vaf': 7.959440154081676e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.951,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 145,
#   'stop': 146,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76734,
#   'chr_stop': 76735,
#   'mutation': ['A>G'],
#   'vaf': 8.75468977028504e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 145,
#   'stop': 146,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76734,
#   'chr_stop': 76735,
#   'mutation': ['A>T'],
#   'vaf': 3.979399934905814e-06,
#   'SIFT': 0.02,
#   'PolyPhen': 0.693,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 146,
#   'stop': 147,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76735,
#   'chr_stop': 76736,
#   'mutation': ['G>T'],
#   'vaf': 9.152550046565011e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.507,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 162,
#   'stop': 164,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76751,
#   'chr_stop': 76753,
#   'mutation': ['CT>C'],
#   'vaf': 2.386840060353279e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 166,
#   'stop': 167,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76755,
#   'chr_stop': 76756,
#   'mutation': ['A>G'],
#   'vaf': 3.9779802136763465e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 172,
#   'stop': 173,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76761,
#   'chr_stop': 76762,
#   'mutation': ['A>G'],
#   'vaf': 3.977950200351188e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 175,
#   'stop': 176,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76764,
#   'chr_stop': 76765,
#   'mutation': ['A>C'],
#   'vaf': 3.9779802136763465e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 176,
#   'stop': 177,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76765,
#   'chr_stop': 76766,
#   'mutation': ['T>C'],
#   'vaf': 1.9889399482053705e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.507,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 181,
#   'stop': 182,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76770,
#   'chr_stop': 76771,
#   'mutation': ['C>T'],
#   'vaf': 0.0013126200065016747,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 193,
#   'stop': 194,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76782,
#   'chr_stop': 76783,
#   'mutation': ['C>T'],
#   'vaf': 3.977720098191639e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 194,
#   'stop': 195,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76783,
#   'chr_stop': 76784,
#   'mutation': ['G>A'],
#   'vaf': 4.375389835331589e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 196,
#   'stop': 197,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76785,
#   'chr_stop': 76786,
#   'mutation': ['C>G'],
#   'vaf': 1.59108003572328e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 196,
#   'stop': 197,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76785,
#   'chr_stop': 76786,
#   'mutation': ['C>T'],
#   'vaf': 2.38661996263545e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 197,
#   'stop': 198,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76786,
#   'chr_stop': 76787,
#   'mutation': ['G>A'],
#   'vaf': 7.955260116432328e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 200,
#   'stop': 201,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76789,
#   'chr_stop': 76790,
#   'mutation': ['C>T'],
#   'vaf': 3.977379947173176e-06,
#   'SIFT': 0.01,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 205,
#   'stop': 206,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76794,
#   'chr_stop': 76795,
#   'mutation': ['T>C'],
#   'vaf': 3.977249889430823e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.483,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 209,
#   'stop': 210,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76798,
#   'chr_stop': 76799,
#   'mutation': ['C>T'],
#   'vaf': 3.97730991608114e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 211,
#   'stop': 212,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76800,
#   'chr_stop': 76801,
#   'mutation': ['G>A'],
#   'vaf': 3.977279902755981e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 214,
#   'stop': 215,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76803,
#   'chr_stop': 76804,
#   'mutation': ['A>T'],
#   'vaf': 3.977189862780506e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.507,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 220,
#   'stop': 221,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76809,
#   'chr_stop': 76810,
#   'mutation': ['C>G'],
#   'vaf': 7.954559805511963e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 229,
#   'stop': 230,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76818,
#   'chr_stop': 76819,
#   'mutation': ['A>G'],
#   'vaf': 1.193249954667408e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 230,
#   'stop': 231,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76819,
#   'chr_stop': 76820,
#   'mutation': ['T>A'],
#   'vaf': 3.977409960498335e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.703,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 248,
#   'stop': 249,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76837,
#   'chr_stop': 76838,
#   'mutation': ['A>G'],
#   'vaf': 3.977690084866481e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 257,
#   'stop': 260,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76846,
#   'chr_stop': 76849,
#   'mutation': ['CTT>C'],
#   'vaf': 3.977600044891005e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 280,
#   'stop': 281,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76869,
#   'chr_stop': 76870,
#   'mutation': ['A>C'],
#   'vaf': 1.1931600056414027e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 280,
#   'stop': 281,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76869,
#   'chr_stop': 76870,
#   'mutation': ['A>G'],
#   'vaf': 3.977189862780506e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 296,
#   'stop': 297,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76885,
#   'chr_stop': 76886,
#   'mutation': ['T>A'],
#   'vaf': 7.954179636726622e-06,
#   'SIFT': 0.01,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 307,
#   'stop': 308,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76896,
#   'chr_stop': 76897,
#   'mutation': ['A>C'],
#   'vaf': 3.977379947173176e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 308,
#   'stop': 309,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76897,
#   'chr_stop': 76898,
#   'mutation': ['C>T'],
#   'vaf': 1.5909099602140486e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 311,
#   'stop': 312,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76900,
#   'chr_stop': 76901,
#   'mutation': ['C>T'],
#   'vaf': 3.977279902755981e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 322,
#   'stop': 323,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76911,
#   'chr_stop': 76912,
#   'mutation': ['G>T'],
#   'vaf': 3.977089818363311e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 328,
#   'stop': 329,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76917,
#   'chr_stop': 76918,
#   'mutation': ['A>C'],
#   'vaf': 3.977159849455347e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 330,
#   'stop': 331,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76919,
#   'chr_stop': 76920,
#   'mutation': ['G>A'],
#   'vaf': 0.0001551140012452379,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 347,
#   'stop': 349,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76936,
#   'chr_stop': 76938,
#   'mutation': ['CT>C'],
#   'vaf': 3.97693020204315e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 370,
#   'stop': 371,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76959,
#   'chr_stop': 76960,
#   'mutation': ['T>G'],
#   'vaf': 1.5912299204501323e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 376,
#   'stop': 377,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76965,
#   'chr_stop': 76966,
#   'mutation': ['G>C'],
#   'vaf': 3.979020220867824e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 376,
#   'stop': 377,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76965,
#   'chr_stop': 76966,
#   'mutation': ['G>T'],
#   'vaf': 3.979020220867824e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 388,
#   'stop': 389,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76977,
#   'chr_stop': 76978,
#   'mutation': ['G>A'],
#   'vaf': 0.00010341800225432962,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 389,
#   'stop': 390,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76978,
#   'chr_stop': 76979,
#   'mutation': ['A>G'],
#   'vaf': 3.977439973823493e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 392,
#   'stop': 393,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76981,
#   'chr_stop': 76982,
#   'mutation': ['C>T'],
#   'vaf': 3.977720098191639e-06,
#   'SIFT': 0.02,
#   'PolyPhen': 0.86,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 401,
#   'stop': 402,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76990,
#   'chr_stop': 76991,
#   'mutation': ['C>T'],
#   'vaf': 3.978169843321666e-06,
#   'SIFT': 0.01,
#   'PolyPhen': 0.908,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 424,
#   'stop': 425,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77013,
#   'chr_stop': 77014,
#   'mutation': ['G>A'],
#   'vaf': 2.7898400730919093e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 432,
#   'stop': 433,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77021,
#   'chr_stop': 77022,
#   'mutation': ['G>A'],
#   'vaf': 7.97867960500298e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 436,
#   'stop': 437,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77025,
#   'chr_stop': 77026,
#   'mutation': ['C>T'],
#   'vaf': 3.988319804193452e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.857,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 440,
#   'stop': 441,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77029,
#   'chr_stop': 77030,
#   'mutation': ['C>T'],
#   'vaf': 1.597059963387437e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 449,
#   'stop': 450,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77038,
#   'chr_stop': 77039,
#   'mutation': ['C>G'],
#   'vaf': 2.8014599593007006e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 451,
#   'stop': 452,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77040,
#   'chr_stop': 77041,
#   'mutation': ['G>A'],
#   'vaf': 1.613509994058404e-05,
#   'SIFT': 0.02,
#   'PolyPhen': 0.811,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 455,
#   'stop': 456,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77044,
#   'chr_stop': 77045,
#   'mutation': ['T>C'],
#   'vaf': 4.055580120621016e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.902,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 460,
#   'stop': 461,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77049,
#   'chr_stop': 77050,
#   'mutation': ['C>G'],
#   'vaf': 4.0682798498892225e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.507,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 460,
#   'stop': 461,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77049,
#   'chr_stop': 77050,
#   'mutation': ['C>T'],
#   'vaf': 4.0682798498892225e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 466,
#   'stop': 467,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77055,
#   'chr_stop': 77056,
#   'mutation': ['T>TA'],
#   'vaf': 4.0892400647862814e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'}]

# %%
combined_wgs_exome_variants = defaultdict(list)
for key in wgs_local_by_gene.keys(): 
    if len(exome_local_by_gene[key]) == 0: 
        combined_wgs_exome_variants[key] = wgs_local_by_gene[key]
    else: 
        combined_wgs_exome_variants[key] = exome_local_by_gene[key]
        combined_wgs_exome_variants[key].append(wgs_local_by_gene[key])

# %%
combined_wgs_exome_variants["DEFB125"]
# Out:
# [{'gene': 'DEFB125',
#   'start': -1,
#   'stop': 0,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68350,
#   'chr_stop': 68351,
#   'mutation': ['A>G'],
#   'vaf': 3.979720077040838e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 11,
#   'stop': 12,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68362,
#   'chr_stop': 68363,
#   'mutation': ['A>C'],
#   'vaf': 3.979179837187985e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 11,
#   'stop': 12,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68362,
#   'chr_stop': 68363,
#   'mutation': ['A>T'],
#   'vaf': 0.0001949800061993301,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 12,
#   'stop': 13,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68363,
#   'chr_stop': 68364,
#   'mutation': ['T>G'],
#   'vaf': 3.9790897972125094e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 21,
#   'stop': 22,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68372,
#   'chr_stop': 68373,
#   'mutation': ['T>C'],
#   'vaf': 3.979399934905814e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 22,
#   'stop': 23,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68373,
#   'chr_stop': 68374,
#   'mutation': ['C>A'],
#   'vaf': 3.97927988160518e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 23,
#   'stop': 24,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68374,
#   'chr_stop': 68375,
#   'mutation': ['A>G'],
#   'vaf': 1.5917399650788866e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 44,
#   'stop': 45,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68395,
#   'chr_stop': 68396,
#   'mutation': ['C>T'],
#   'vaf': 0.0015282999956980348,
#   'SIFT': 0.03,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 45,
#   'stop': 46,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68396,
#   'chr_stop': 68397,
#   'mutation': ['G>A'],
#   'vaf': 1.5919800716801547e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 50,
#   'stop': 51,
#   'strand': '+',
#   'exon': 0,
#   'chr': '20',
#   'chr_start': 68401,
#   'chr_stop': 68402,
#   'mutation': ['A>G'],
#   'vaf': 7.96013955550734e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 58,
#   'stop': 59,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76647,
#   'chr_stop': 76648,
#   'mutation': ['A>G'],
#   'vaf': 4.094470114068827e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.483,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 59,
#   'stop': 60,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76648,
#   'chr_stop': 76649,
#   'mutation': ['G>T'],
#   'vaf': 8.121889550238848e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.766,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 60,
#   'stop': 61,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76649,
#   'chr_stop': 76650,
#   'mutation': ['C>A'],
#   'vaf': 1.6239999240497127e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.766,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 64,
#   'stop': 65,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76653,
#   'chr_stop': 76654,
#   'mutation': ['G>T'],
#   'vaf': 3.234569885535166e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 68,
#   'stop': 69,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76657,
#   'chr_stop': 76658,
#   'mutation': ['C>A'],
#   'vaf': 1.2116400284867268e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 70,
#   'stop': 71,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76659,
#   'chr_stop': 76660,
#   'mutation': ['C>G'],
#   'vaf': 4.03534977522213e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 71,
#   'stop': 72,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76660,
#   'chr_stop': 76661,
#   'mutation': ['A>C'],
#   'vaf': 8.064450412348378e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 74,
#   'stop': 75,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76663,
#   'chr_stop': 76664,
#   'mutation': ['A>C'],
#   'vaf': 4.023499968752731e-06,
#   'SIFT': 0.01,
#   'PolyPhen': 0.913,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 80,
#   'stop': 81,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76669,
#   'chr_stop': 76670,
#   'mutation': ['G>T'],
#   'vaf': 4.019620064354967e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 92,
#   'stop': 93,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76681,
#   'chr_stop': 76682,
#   'mutation': ['T>C'],
#   'vaf': 3.987299805885414e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 99,
#   'stop': 100,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76688,
#   'chr_stop': 76689,
#   'mutation': ['T>A'],
#   'vaf': 1.1952100066991989e-05,
#   'SIFT': 0.01,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 100,
#   'stop': 101,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76689,
#   'chr_stop': 76690,
#   'mutation': ['T>C'],
#   'vaf': 3.984159775427543e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.951,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 101,
#   'stop': 102,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76690,
#   'chr_stop': 76691,
#   'mutation': ['G>T'],
#   'vaf': 1.1952999557252042e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.951,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 102,
#   'stop': 103,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76691,
#   'chr_stop': 76692,
#   'mutation': ['C>A'],
#   'vaf': 3.984860086347908e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 107,
#   'stop': 108,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76696,
#   'chr_stop': 76697,
#   'mutation': ['G>A'],
#   'vaf': 3.983209808211541e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 109,
#   'stop': 110,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76698,
#   'chr_stop': 76699,
#   'mutation': ['C>T'],
#   'vaf': 1.5934199836920016e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 112,
#   'stop': 113,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76701,
#   'chr_stop': 76702,
#   'mutation': ['T>G'],
#   'vaf': 3.9825699786888435e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.849,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 113,
#   'stop': 114,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76702,
#   'chr_stop': 76703,
#   'mutation': ['G>A'],
#   'vaf': 1.5929699657135643e-05,
#   'SIFT': 0.0,
#   'PolyPhen': 0.951,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 113,
#   'stop': 114,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76702,
#   'chr_stop': 76703,
#   'mutation': ['G>C'],
#   'vaf': 3.9824099076213315e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.849,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 127,
#   'stop': 128,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76716,
#   'chr_stop': 76717,
#   'mutation': ['A>G'],
#   'vaf': 3.9809201552998275e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.849,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 137,
#   'stop': 138,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76726,
#   'chr_stop': 76727,
#   'mutation': ['T>C'],
#   'vaf': 3.979780103691155e-06,
#   'SIFT': 0.01,
#   'PolyPhen': 0.973,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 143,
#   'stop': 144,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76732,
#   'chr_stop': 76733,
#   'mutation': ['G>A'],
#   'vaf': 7.959440154081676e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.951,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 145,
#   'stop': 146,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76734,
#   'chr_stop': 76735,
#   'mutation': ['A>G'],
#   'vaf': 8.75468977028504e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 145,
#   'stop': 146,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76734,
#   'chr_stop': 76735,
#   'mutation': ['A>T'],
#   'vaf': 3.979399934905814e-06,
#   'SIFT': 0.02,
#   'PolyPhen': 0.693,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 146,
#   'stop': 147,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76735,
#   'chr_stop': 76736,
#   'mutation': ['G>T'],
#   'vaf': 9.152550046565011e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.507,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 162,
#   'stop': 164,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76751,
#   'chr_stop': 76753,
#   'mutation': ['CT>C'],
#   'vaf': 2.386840060353279e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 166,
#   'stop': 167,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76755,
#   'chr_stop': 76756,
#   'mutation': ['A>G'],
#   'vaf': 3.9779802136763465e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 172,
#   'stop': 173,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76761,
#   'chr_stop': 76762,
#   'mutation': ['A>G'],
#   'vaf': 3.977950200351188e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 175,
#   'stop': 176,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76764,
#   'chr_stop': 76765,
#   'mutation': ['A>C'],
#   'vaf': 3.9779802136763465e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 176,
#   'stop': 177,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76765,
#   'chr_stop': 76766,
#   'mutation': ['T>C'],
#   'vaf': 1.9889399482053705e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.507,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 181,
#   'stop': 182,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76770,
#   'chr_stop': 76771,
#   'mutation': ['C>T'],
#   'vaf': 0.0013126200065016747,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 193,
#   'stop': 194,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76782,
#   'chr_stop': 76783,
#   'mutation': ['C>T'],
#   'vaf': 3.977720098191639e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 194,
#   'stop': 195,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76783,
#   'chr_stop': 76784,
#   'mutation': ['G>A'],
#   'vaf': 4.375389835331589e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 196,
#   'stop': 197,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76785,
#   'chr_stop': 76786,
#   'mutation': ['C>G'],
#   'vaf': 1.59108003572328e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 196,
#   'stop': 197,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76785,
#   'chr_stop': 76786,
#   'mutation': ['C>T'],
#   'vaf': 2.38661996263545e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 197,
#   'stop': 198,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76786,
#   'chr_stop': 76787,
#   'mutation': ['G>A'],
#   'vaf': 7.955260116432328e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 200,
#   'stop': 201,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76789,
#   'chr_stop': 76790,
#   'mutation': ['C>T'],
#   'vaf': 3.977379947173176e-06,
#   'SIFT': 0.01,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 205,
#   'stop': 206,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76794,
#   'chr_stop': 76795,
#   'mutation': ['T>C'],
#   'vaf': 3.977249889430823e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.483,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 209,
#   'stop': 210,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76798,
#   'chr_stop': 76799,
#   'mutation': ['C>T'],
#   'vaf': 3.97730991608114e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 211,
#   'stop': 212,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76800,
#   'chr_stop': 76801,
#   'mutation': ['G>A'],
#   'vaf': 3.977279902755981e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 214,
#   'stop': 215,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76803,
#   'chr_stop': 76804,
#   'mutation': ['A>T'],
#   'vaf': 3.977189862780506e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.507,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 220,
#   'stop': 221,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76809,
#   'chr_stop': 76810,
#   'mutation': ['C>G'],
#   'vaf': 7.954559805511963e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 229,
#   'stop': 230,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76818,
#   'chr_stop': 76819,
#   'mutation': ['A>G'],
#   'vaf': 1.193249954667408e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 230,
#   'stop': 231,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76819,
#   'chr_stop': 76820,
#   'mutation': ['T>A'],
#   'vaf': 3.977409960498335e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.703,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 248,
#   'stop': 249,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76837,
#   'chr_stop': 76838,
#   'mutation': ['A>G'],
#   'vaf': 3.977690084866481e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 257,
#   'stop': 260,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76846,
#   'chr_stop': 76849,
#   'mutation': ['CTT>C'],
#   'vaf': 3.977600044891005e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 280,
#   'stop': 281,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76869,
#   'chr_stop': 76870,
#   'mutation': ['A>C'],
#   'vaf': 1.1931600056414027e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 280,
#   'stop': 281,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76869,
#   'chr_stop': 76870,
#   'mutation': ['A>G'],
#   'vaf': 3.977189862780506e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 296,
#   'stop': 297,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76885,
#   'chr_stop': 76886,
#   'mutation': ['T>A'],
#   'vaf': 7.954179636726622e-06,
#   'SIFT': 0.01,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 307,
#   'stop': 308,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76896,
#   'chr_stop': 76897,
#   'mutation': ['A>C'],
#   'vaf': 3.977379947173176e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 308,
#   'stop': 309,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76897,
#   'chr_stop': 76898,
#   'mutation': ['C>T'],
#   'vaf': 1.5909099602140486e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 311,
#   'stop': 312,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76900,
#   'chr_stop': 76901,
#   'mutation': ['C>T'],
#   'vaf': 3.977279902755981e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 322,
#   'stop': 323,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76911,
#   'chr_stop': 76912,
#   'mutation': ['G>T'],
#   'vaf': 3.977089818363311e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 328,
#   'stop': 329,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76917,
#   'chr_stop': 76918,
#   'mutation': ['A>C'],
#   'vaf': 3.977159849455347e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 330,
#   'stop': 331,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76919,
#   'chr_stop': 76920,
#   'mutation': ['G>A'],
#   'vaf': 0.0001551140012452379,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 347,
#   'stop': 349,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76936,
#   'chr_stop': 76938,
#   'mutation': ['CT>C'],
#   'vaf': 3.97693020204315e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 370,
#   'stop': 371,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76959,
#   'chr_stop': 76960,
#   'mutation': ['T>G'],
#   'vaf': 1.5912299204501323e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 376,
#   'stop': 377,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76965,
#   'chr_stop': 76966,
#   'mutation': ['G>C'],
#   'vaf': 3.979020220867824e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 376,
#   'stop': 377,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76965,
#   'chr_stop': 76966,
#   'mutation': ['G>T'],
#   'vaf': 3.979020220867824e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 388,
#   'stop': 389,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76977,
#   'chr_stop': 76978,
#   'mutation': ['G>A'],
#   'vaf': 0.00010341800225432962,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 389,
#   'stop': 390,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76978,
#   'chr_stop': 76979,
#   'mutation': ['A>G'],
#   'vaf': 3.977439973823493e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 392,
#   'stop': 393,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76981,
#   'chr_stop': 76982,
#   'mutation': ['C>T'],
#   'vaf': 3.977720098191639e-06,
#   'SIFT': 0.02,
#   'PolyPhen': 0.86,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 401,
#   'stop': 402,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 76990,
#   'chr_stop': 76991,
#   'mutation': ['C>T'],
#   'vaf': 3.978169843321666e-06,
#   'SIFT': 0.01,
#   'PolyPhen': 0.908,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 424,
#   'stop': 425,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77013,
#   'chr_stop': 77014,
#   'mutation': ['G>A'],
#   'vaf': 2.7898400730919093e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 432,
#   'stop': 433,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77021,
#   'chr_stop': 77022,
#   'mutation': ['G>A'],
#   'vaf': 7.97867960500298e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 436,
#   'stop': 437,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77025,
#   'chr_stop': 77026,
#   'mutation': ['C>T'],
#   'vaf': 3.988319804193452e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.857,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 440,
#   'stop': 441,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77029,
#   'chr_stop': 77030,
#   'mutation': ['C>T'],
#   'vaf': 1.597059963387437e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 449,
#   'stop': 450,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77038,
#   'chr_stop': 77039,
#   'mutation': ['C>G'],
#   'vaf': 2.8014599593007006e-05,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 451,
#   'stop': 452,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77040,
#   'chr_stop': 77041,
#   'mutation': ['G>A'],
#   'vaf': 1.613509994058404e-05,
#   'SIFT': 0.02,
#   'PolyPhen': 0.811,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 455,
#   'stop': 456,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77044,
#   'chr_stop': 77045,
#   'mutation': ['T>C'],
#   'vaf': 4.055580120621016e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.902,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 460,
#   'stop': 461,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77049,
#   'chr_stop': 77050,
#   'mutation': ['C>G'],
#   'vaf': 4.0682798498892225e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.507,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 460,
#   'stop': 461,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77049,
#   'chr_stop': 77050,
#   'mutation': ['C>T'],
#   'vaf': 4.0682798498892225e-06,
#   'SIFT': 0.0,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  {'gene': 'DEFB125',
#   'start': 466,
#   'stop': 467,
#   'strand': '+',
#   'exon': 1,
#   'chr': '20',
#   'chr_start': 77055,
#   'chr_stop': 77056,
#   'mutation': ['T>TA'],
#   'vaf': 4.0892400647862814e-06,
#   'SIFT': 0.13,
#   'PolyPhen': 0.5,
#   'type': 'exome sequencing'},
#  [{'gene': 'DEFB125',
#    'start': 5,
#    'stop': 6,
#    'strand': '+',
#    'exon': 0,
#    'chr': '20',
#    'chr_start': 68356,
#    'chr_stop': 68357,
#    'mutation': ['A>G'],
#    'vaf': 3.18552010867279e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 11,
#    'stop': 12,
#    'strand': '+',
#    'exon': 0,
#    'chr': '20',
#    'chr_start': 68362,
#    'chr_stop': 68363,
#    'mutation': ['A>T'],
#    'vaf': 0.00012747000437229872,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 22,
#    'stop': 23,
#    'strand': '+',
#    'exon': 0,
#    'chr': '20',
#    'chr_start': 68373,
#    'chr_stop': 68374,
#    'mutation': ['C>A'],
#    'vaf': 3.1859301088843495e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 32,
#    'stop': 33,
#    'strand': '+',
#    'exon': 0,
#    'chr': '20',
#    'chr_start': 68383,
#    'chr_stop': 68384,
#    'mutation': ['G>C'],
#    'vaf': 3.18552010867279e-05,
#    'SIFT': 0.0,
#    'PolyPhen': 0.455,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 44,
#    'stop': 45,
#    'strand': '+',
#    'exon': 0,
#    'chr': '20',
#    'chr_start': 68395,
#    'chr_stop': 68396,
#    'mutation': ['C>T'],
#    'vaf': 0.0014653400285169482,
#    'SIFT': 0.03,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 45,
#    'stop': 46,
#    'strand': '+',
#    'exon': 0,
#    'chr': '20',
#    'chr_start': 68396,
#    'chr_stop': 68397,
#    'mutation': ['G>A'],
#    'vaf': 3.18491984216962e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 64,
#    'stop': 65,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76653,
#    'chr_stop': 76654,
#    'mutation': ['G>T'],
#    'vaf': 0.00012750999303534627,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 95,
#    'stop': 96,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76684,
#    'chr_stop': 76685,
#    'mutation': ['G>A'],
#    'vaf': 3.184709930792451e-05,
#    'SIFT': 0.0,
#    'PolyPhen': 0.993,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 109,
#    'stop': 110,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76698,
#    'chr_stop': 76699,
#    'mutation': ['C>T'],
#    'vaf': 6.369830225594342e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 113,
#    'stop': 114,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76702,
#    'chr_stop': 76703,
#    'mutation': ['G>A'],
#    'vaf': 3.184509841958061e-05,
#    'SIFT': 0.0,
#    'PolyPhen': 0.951,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 145,
#    'stop': 146,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76734,
#    'chr_stop': 76735,
#    'mutation': ['A>G'],
#    'vaf': 3.183700027875602e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 146,
#    'stop': 147,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76735,
#    'chr_stop': 76736,
#    'mutation': ['G>T'],
#    'vaf': 3.1840998417465016e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.507,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 181,
#    'stop': 182,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76770,
#    'chr_stop': 76771,
#    'mutation': ['C>T'],
#    'vaf': 0.0011463500559329987,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 193,
#    'stop': 194,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76782,
#    'chr_stop': 76783,
#    'mutation': ['C>T'],
#    'vaf': 3.1853200198384e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 196,
#    'stop': 197,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76785,
#    'chr_stop': 76786,
#    'mutation': ['C>T'],
#    'vaf': 3.183700027875602e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 197,
#    'stop': 198,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76786,
#    'chr_stop': 76787,
#    'mutation': ['G>C'],
#    'vaf': 3.18511993100401e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 272,
#    'stop': 273,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76861,
#    'chr_stop': 76862,
#    'mutation': ['C>T'],
#    'vaf': 3.186129833920859e-05,
#    'SIFT': 0.0,
#    'PolyPhen': 0.908,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 330,
#    'stop': 331,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76919,
#    'chr_stop': 76920,
#    'mutation': ['G>A'],
#    'vaf': 0.0006371460040099919,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 386,
#    'stop': 387,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76975,
#    'chr_stop': 76976,
#    'mutation': ['C>T'],
#    'vaf': 3.18552010867279e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 388,
#    'stop': 389,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76977,
#    'chr_stop': 76978,
#    'mutation': ['G>A'],
#    'vaf': 6.369430047925562e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 404,
#    'stop': 405,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 76993,
#    'chr_stop': 76994,
#    'mutation': ['C>G'],
#    'vaf': 3.1843101169215515e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 424,
#    'stop': 425,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 77013,
#    'chr_stop': 77014,
#    'mutation': ['G>A'],
#    'vaf': 3.186539834132418e-05,
#    'SIFT': 0.13,
#    'PolyPhen': 0.5,
#    'type': 'whole genome sequencing'},
#   {'gene': 'DEFB125',
#    'start': 436,
#    'stop': 437,
#    'strand': '+',
#    'exon': 1,
#    'chr': '20',
#    'chr_start': 77025,
#    'chr_stop': 77026,
#    'mutation': ['C>T'],
#    'vaf': 3.18511993100401e-05,
#    'SIFT': 0.0,
#    'PolyPhen': 0.857,
#    'type': 'whole genome sequencing'}]]

# %%
## Read in the VCF file 
vcf = cyvcf2.VCF(vcf_path)

## Get the VEP description fields into a 'list'
kcsq = vcf["vep"]["Description"].split(":")[1].strip(' "').split("|")

## Read in the gff transcript file and subset calls from chr20
transcripts = exter.read_gff(gff_path)
transcripts20 = transcripts["20"] # get chr20

## Make an empty dictionary 
local_by_gene = defaultdict(list)

## For each variant in the VCF file: 
for variant in vcf:
    ## Remove variants that have "None, PASS, SEGDUP, or LCR" as the filter result
    ## NOTE: 'continue' will remove variants without these FILTER results
    if not (variant.FILTER is None or variant.FILTER in ["PASS", "SEGDUP", "LCR"]):
            continue
    ## Get the variant 'INFO' field from the VCF file for each variant
    info = variant.INFO
    ## Set the functional consequence of the variant to 'False'
    any_functional = False
    ## Merge the kcsq description keys with 
    csqs = [dict(zip(kcsq, c.split("|"))) for c in info['vep'].split(",")]

    ## For all variant/consequences that are within protein_coding regions
    for csq in (c for c in csqs if c['BIOTYPE'] == 'protein_coding'):
        ## NOTE: 'continue' will ignore variants that are intronic 
        if csq['Feature'] == '' or csq['EXON'] == '': 
            continue #or csq['cDNA_position'] == '': continue
        ## Check to see if the variant's consequence is functional (based on the mutation types listed above)
        ## NOTE: 'continue' will ignore variants that are not functional
        if not isfunctional(csq): 
            continue
        ## Assigns True to the variant as functional if it is NOT intronic and is deemed as functional by the 'isfunctional' function
        any_functional = True

        ## Get the exonic positions of the variants
        local = transcripts20.localize(variant.start, variant.end)

        ## Get the VAF of the variant
        vaf = variant.INFO.get('AF')

        ## Get the SIFT/PolyPhen results (IS THIS RIGHT)
        SIFT = csq["SIFT"]
        PolyPhen = csq["PolyPhen"]
                
        ## Get the reference allele 
        ref_allele = variant.REF

        ## Get string for the mutation 
        mut = []
        for alt in variant.ALT: 
            mut.append(ref_allele + ">" + alt) 
        
        ## Remove variants that do not meet a specific VAF cutoff 
        # if vaf < 0.0000001: continue
        
        ## Perform SIFT and Polyphen filters to remove the least delterious/damaging variant(s)
        ## Go through each pair of scores and check if the varaint has SIFT and PolyPhen scores
        sift_score = sift_cutoff + 0.1
        polyphen_score = polyphen_cutoff - 0.1
        if sift_polyphen_filter == True: 
            if re.findall("deleterious", SIFT):
                sift_score = float(re.split('\)', re.split('\(', SIFT)[1])[0])
            if re.findall("damaging", PolyPhen):
                polyphen_score = float(re.split('\)', re.split('\(', PolyPhen)[1])[0])
            ## SIFT score has to be below the sift_cutoff to pass 
            ## PolyPhen score has to be above the polyphen_cutoff to pass 
            if not sift_score < sift_cutoff and polyphen_score > polyphen_cutoff:
                continue

        ## Remove variants that are found in duplicated segments 
        #if variant.INFO.get('segdup') == True or variant.INFO.get('lcr'): continue

        ## Get the chromosome 
        chr = variant.CHROM

        for l in local:
            l["chr"] = chr
            l["chr_start"] = variant.start
            l["chr_stop"] = variant.end
            l["mutation"] = mut
            l["vaf"] = vaf
            l["SIFT"] = sift_score
            l["PolyPhen"] = polyphen_score
            local_by_gene[l["gene"]].append(l)
        break

# %%
local_by_gene[test_key]
